# %%
#dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
#set path 
us_vacc_path = "resources/vaccinations/us_state_vaccinations.csv"
state_business_path = "resources/State.csv"
mobility_path= "resources/Global_Mobility_Report.csv"
us_path = "resources/2021_US_Region_Mobility_Report.csv"

# %%
#store data into pandas dataframe
vacc_df = pd.read_csv(us_vacc_path)
vacc_df
# Out:
#             date location  total_vaccinations  total_distributed  \
# 0     2021-01-12  Alabama             78134.0           377025.0
# 1     2021-01-13  Alabama             84040.0           378975.0
# 2     2021-01-14  Alabama             92300.0           435350.0
# 3     2021-01-15  Alabama            100567.0           444650.0
# 4     2021-01-16  Alabama                 NaN                NaN
# ...          ...      ...                 ...                ...
# 2813  2021-02-19  Wyoming            124310.0           150005.0
# 2814  2021-02-20  Wyoming            129060.0           150905.0
# 2815  2021-02-21  Wyoming            129470.0           150905.0
# 2816  2021-02-22  Wyoming            135635.0           150905.0
# 2817  2021-02-23  Wyoming            136163.0           167025.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0               70861.0                                 0.15
# 1               74792.0                                 0.19
# 2               80480.0                                  NaN
# 3               86956.0                                 0.27
# 4                   NaN                                  NaN
# ...                 ...                                  ...
# 2813            87289.0                                 6.33
# 2814            89346.0                                 6.79
# 2815            89605.0                                 6.82
# 2816            91931.0                                 7.48
# 2817            92151.0                                 7.53
#
#       total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                               1.59                   7270.0
# 1                               1.71                   9245.0
# 2                               1.88                      NaN
# 3                               2.05                  13488.0
# 4                                NaN                      NaN
# ...                              ...                      ...
# 2813                           21.48                  36651.0
# 2814                           22.30                  39323.0
# 2815                           22.37                  39474.0
# 2816                           23.44                  43289.0
# 2817                           23.53                  43596.0
#
#       people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                              1.44                     7.69
# 1                              1.52                     7.73
# 2                              1.64                     8.88
# 3                              1.77                     9.07
# 4                               NaN                      NaN
# ...                             ...                      ...
# 2813                          15.08                    25.92
# 2814                          15.44                    26.07
# 2815                          15.48                    26.07
# 2816                          15.88                    26.07
# 2817                          15.92                    28.86
#
#       daily_vaccinations_raw  daily_vaccinations  \
# 0                        NaN                 NaN
# 1                     5906.0              5906.0
# 2                     8260.0              7083.0
# 3                     8267.0              7478.0
# 4                     7557.0              7498.0
# ...                      ...                 ...
# 2813                 18884.0              5025.0
# 2814                  4750.0              5703.0
# 2815                   410.0              4339.0
# 2816                  6165.0              5142.0
# 2817                   528.0              5140.0
#
#       daily_vaccinations_per_million  share_doses_used
# 0                                NaN             0.207
# 1                             1205.0             0.222
# 2                             1445.0             0.212
# 3                             1525.0             0.226
# 4                             1529.0               NaN
# ...                              ...               ...
# 2813                          8682.0             0.829
# 2814                          9854.0             0.855
# 2815                          7497.0             0.858
# 2816                          8885.0             0.899
# 2817                          8881.0             0.815
#
# [2818 rows x 14 columns]

# %%
#select specific columns
vacc_df = vacc_df[["date", "location", "people_vaccinated", "people_fully_vaccinated"]]
vacc_df
# Out:
#             date location  people_vaccinated  people_fully_vaccinated
# 0     2021-01-12  Alabama            70861.0                   7270.0
# 1     2021-01-13  Alabama            74792.0                   9245.0
# 2     2021-01-14  Alabama            80480.0                      NaN
# 3     2021-01-15  Alabama            86956.0                  13488.0
# 4     2021-01-16  Alabama                NaN                      NaN
# ...          ...      ...                ...                      ...
# 2813  2021-02-19  Wyoming            87289.0                  36651.0
# 2814  2021-02-20  Wyoming            89346.0                  39323.0
# 2815  2021-02-21  Wyoming            89605.0                  39474.0
# 2816  2021-02-22  Wyoming            91931.0                  43289.0
# 2817  2021-02-23  Wyoming            92151.0                  43596.0
#
# [2818 rows x 4 columns]

# %%
#drop NA colums 
#filter data from 2019 on 
vacc_df = vacc_df.dropna(axis="index")
vacc_df = vacc_df.loc[vacc_df["date"] >= "2019-01-01"]
vacc_df
# Out:
#             date location  people_vaccinated  people_fully_vaccinated
# 0     2021-01-12  Alabama            70861.0                   7270.0
# 1     2021-01-13  Alabama            74792.0                   9245.0
# 3     2021-01-15  Alabama            86956.0                  13488.0
# 7     2021-01-19  Alabama           114319.0                  16346.0
# 8     2021-01-20  Alabama           121113.0                  17956.0
# ...          ...      ...                ...                      ...
# 2813  2021-02-19  Wyoming            87289.0                  36651.0
# 2814  2021-02-20  Wyoming            89346.0                  39323.0
# 2815  2021-02-21  Wyoming            89605.0                  39474.0
# 2816  2021-02-22  Wyoming            91931.0                  43289.0
# 2817  2021-02-23  Wyoming            92151.0                  43596.0
#
# [2405 rows x 4 columns]

# %%
vacc_df = vacc_df.rename(columns={"location":"state"})

# %%
vacc_df = vacc_df.set_index("date")
vacc_df
# Out:
#               state  people_vaccinated  people_fully_vaccinated
# date
# 2021-01-12  Alabama            70861.0                   7270.0
# 2021-01-13  Alabama            74792.0                   9245.0
# 2021-01-15  Alabama            86956.0                  13488.0
# 2021-01-19  Alabama           114319.0                  16346.0
# 2021-01-20  Alabama           121113.0                  17956.0
# ...             ...                ...                      ...
# 2021-02-19  Wyoming            87289.0                  36651.0
# 2021-02-20  Wyoming            89346.0                  39323.0
# 2021-02-21  Wyoming            89605.0                  39474.0
# 2021-02-22  Wyoming            91931.0                  43289.0
# 2021-02-23  Wyoming            92151.0                  43596.0
#
# [2405 rows x 3 columns]

# %%
state_business_df = pd.read_csv(state_business_path)
state_business_df = state_business_df[["Year", "Week", "State", "Business Applications", "Applications from Corporations"]]
state_business_df
# Out:
#        Year  Week State  Business Applications  Applications from Corporations
# 0      2006     1    AK                     90                              30
# 1      2006     2    AK                     90                              30
# 2      2006     3    AK                    130                              40
# 3      2006     4    AK                    100                              20
# 4      2006     5    AK                    150                              30
# ...     ...   ...   ...                    ...                             ...
# 40744  2021    13    WY                    670                              90
# 40745  2021    14    WY                    700                             100
# 40746  2021    15    WY                    760                             110
# 40747  2021    16    WY                    680                             100
# 40748  2021    17    WY                    740                             110
#
# [40749 rows x 5 columns]

# %%
#Change abbreviation 
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}


abbrev_us_state = dict(map(reversed, us_state_abbrev.items()))

state_business_df = state_business_df.replace({"State": abbrev_us_state})
state_business_df
# Out:
#        Year  Week    State  Business Applications  \
# 0      2006     1   Alaska                     90
# 1      2006     2   Alaska                     90
# 2      2006     3   Alaska                    130
# 3      2006     4   Alaska                    100
# 4      2006     5   Alaska                    150
# ...     ...   ...      ...                    ...
# 40744  2021    13  Wyoming                    670
# 40745  2021    14  Wyoming                    700
# 40746  2021    15  Wyoming                    760
# 40747  2021    16  Wyoming                    680
# 40748  2021    17  Wyoming                    740
#
#        Applications from Corporations
# 0                                  30
# 1                                  30
# 2                                  40
# 3                                  20
# 4                                  30
# ...                               ...
# 40744                              90
# 40745                             100
# 40746                             110
# 40747                             100
# 40748                             110
#
# [40749 rows x 5 columns]

# %%
state_business_df = state_business_df.loc[state_business_df["Year"] >= 2021]
state_business_df
# Out:
#        Year  Week    State  Business Applications  \
# 782    2021     1   Alaska                    130
# 783    2021     2   Alaska                    240
# 784    2021     3   Alaska                    170
# 785    2021     4   Alaska                    210
# 786    2021     5   Alaska                    210
# ...     ...   ...      ...                    ...
# 40744  2021    13  Wyoming                    670
# 40745  2021    14  Wyoming                    700
# 40746  2021    15  Wyoming                    760
# 40747  2021    16  Wyoming                    680
# 40748  2021    17  Wyoming                    740
#
#        Applications from Corporations
# 782                                20
# 783                                20
# 784                                20
# 785                                10
# 786                                10
# ...                               ...
# 40744                              90
# 40745                             100
# 40746                             110
# 40747                             100
# 40748                             110
#
# [867 rows x 5 columns]

# %%
us_mobility = pd.read_csv(us_path)
us_mobility
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 408601                  US  United States      Wyoming  Weston County
# 408602                  US  United States      Wyoming  Weston County
# 408603                  US  United States      Wyoming  Weston County
# 408604                  US  United States      Wyoming  Weston County
# 408605                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 0              NaN             NaN               NaN
# 1              NaN             NaN               NaN
# 2              NaN             NaN               NaN
# 3              NaN             NaN               NaN
# 4              NaN             NaN               NaN
# ...            ...             ...               ...
# 408601         NaN             NaN           56045.0
# 408602         NaN             NaN           56045.0
# 408603         NaN             NaN           56045.0
# 408604         NaN             NaN           56045.0
# 408605         NaN             NaN           56045.0
#
#                            place_id        date  \
# 0       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-01
# 1       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-02
# 2       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-03
# 3       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-04
# 4       ChIJCzYy5IS16lQRQrfeQ5K5Oxw  2021-01-05
# ...                             ...         ...
# 408601  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-05-31
# 408602  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-06-01
# 408603  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-06-02
# 408604  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-06-03
# 408605  ChIJd4Rqhed3YocR7ubT5-HgoJg  2021-06-04
#
#         retail_and_recreation_percent_change_from_baseline  \
# 0                                                   -47.0
# 1                                                   -26.0
# 2                                                   -27.0
# 3                                                   -19.0
# 4                                                   -20.0
# ...                                                   ...
# 408601                                                NaN
# 408602                                                NaN
# 408603                                                NaN
# 408604                                                NaN
# 408605                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                   -37.0
# 1                                                   -13.0
# 2                                                   -16.0
# 3                                                    -8.0
# 4                                                    -6.0
# ...                                                   ...
# 408601                                                NaN
# 408602                                                NaN
# 408603                                                NaN
# 408604                                                NaN
# 408605                                                NaN
#
#         parks_percent_change_from_baseline  \
# 0                                    -21.0
# 1                                    -14.0
# 2                                    -24.0
# 3                                    -23.0
# 4                                    -20.0
# ...                                    ...
# 408601                                 NaN
# 408602                                 NaN
# 408603                                 NaN
# 408604                                 NaN
# 408605                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 0                                               -62.0
# 1                                               -33.0
# 2                                               -33.0
# 3                                               -39.0
# 4                                               -39.0
# ...                                               ...
# 408601                                            NaN
# 408602                                            NaN
# 408603                                            NaN
# 408604                                            NaN
# 408605                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 0                                         -75.0
# 1                                         -21.0
# 2                                         -17.0
# 3                                         -34.0
# 4                                         -34.0
# ...                                         ...
# 408601                                    -66.0
# 408602                                    -36.0
# 408603                                    -34.0
# 408604                                    -35.0
# 408605                                    -41.0
#
#         residential_percent_change_from_baseline
# 0                                           27.0
# 1                                            9.0
# 2                                            7.0
# 3                                           12.0
# 4                                           12.0
# ...                                          ...
# 408601                                       NaN
# 408602                                       NaN
# 408603                                       NaN
# 408604                                       NaN
# 408605                                       NaN
#
# [408606 rows x 15 columns]

# %%
us_mobility = us_mobility[["sub_region_1", "date", "retail_and_recreation_percent_change_from_baseline",
                          "grocery_and_pharmacy_percent_change_from_baseline", "parks_percent_change_from_baseline",
                          "transit_stations_percent_change_from_baseline", "workplaces_percent_change_from_baseline",
                          "residential_percent_change_from_baseline"]]
us_mobility = us_mobility.dropna()

us_mobility = us_mobility.rename(columns={"sub_region_1":"state","retail_and_recreation_percent_change_from_baseline":"retail_and_rec_percent_change",
                                "grocery_and_pharmacy_percent_change_from_baseline":"grocery_and_pharmacy_percent_change",
                                "parks_percent_change_from_baseline":"parks_percent_change","transit_stations_percent_change_from_baseline":
                                "transit_stations_percent_change", "workplaces_percent_change_from_baseline":"workplace_percent_change",
                                "residential_percent_change_from_baseline":"residential_percent_change"})
us_mobility
# Out:
#           state        date  retail_and_rec_percent_change  \
# 157     Alabama  2021-01-01                          -44.0
# 158     Alabama  2021-01-02                          -19.0
# 159     Alabama  2021-01-03                          -16.0
# 160     Alabama  2021-01-04                           -5.0
# 161     Alabama  2021-01-05                          -10.0
# ...         ...         ...                            ...
# 407367  Wyoming  2021-05-28                            7.0
# 407371  Wyoming  2021-06-01                            7.0
# 407372  Wyoming  2021-06-02                            7.0
# 407373  Wyoming  2021-06-03                           10.0
# 407374  Wyoming  2021-06-04                           -5.0
#
#         grocery_and_pharmacy_percent_change  parks_percent_change  \
# 157                                   -30.0                 -16.0
# 158                                    -8.0                  -2.0
# 159                                    -8.0                  -7.0
# 160                                     2.0                  -9.0
# 161                                    -1.0                 -14.0
# ...                                     ...                   ...
# 407367                                 15.0                 103.0
# 407371                                 17.0                 106.0
# 407372                                 14.0                 103.0
# 407373                                 15.0                  87.0
# 407374                                 13.0                 100.0
#
#         transit_stations_percent_change  workplace_percent_change  \
# 157                               -46.0                     -72.0
# 158                                -8.0                     -19.0
# 159                                -1.0                     -17.0
# 160                                -9.0                     -26.0
# 161                               -12.0                     -25.0
# ...                                 ...                       ...
# 407367                             11.0                     -24.0
# 407371                              3.0                     -21.0
# 407372                             -4.0                     -21.0
# 407373                              6.0                     -21.0
# 407374                              9.0                     -21.0
#
#         residential_percent_change
# 157                           26.0
# 158                            7.0
# 159                            6.0
# 160                            8.0
# 161                            8.0
# ...                            ...
# 407367                         0.0
# 407371                         1.0
# 407372                         1.0
# 407373                        -1.0
# 407374                         0.0
#
# [84846 rows x 8 columns]

# %%
merge_df = pd.merge(vacc_df, us_mobility)
merge_df
# Out:
#            state  people_vaccinated  people_fully_vaccinated        date  \
# 0        Alabama            70861.0                   7270.0  2021-01-01
# 1        Alabama            70861.0                   7270.0  2021-01-02
# 2        Alabama            70861.0                   7270.0  2021-01-03
# 3        Alabama            70861.0                   7270.0  2021-01-04
# 4        Alabama            70861.0                   7270.0  2021-01-05
# ...          ...                ...                      ...         ...
# 3076954  Wyoming            92151.0                  43596.0  2021-05-28
# 3076955  Wyoming            92151.0                  43596.0  2021-06-01
# 3076956  Wyoming            92151.0                  43596.0  2021-06-02
# 3076957  Wyoming            92151.0                  43596.0  2021-06-03
# 3076958  Wyoming            92151.0                  43596.0  2021-06-04
#
#          retail_and_rec_percent_change  grocery_and_pharmacy_percent_change  \
# 0                                -44.0                                -30.0
# 1                                -19.0                                 -8.0
# 2                                -16.0                                 -8.0
# 3                                 -5.0                                  2.0
# 4                                -10.0                                 -1.0
# ...                                ...                                  ...
# 3076954                            7.0                                 15.0
# 3076955                            7.0                                 17.0
# 3076956                            7.0                                 14.0
# 3076957                           10.0                                 15.0
# 3076958                           -5.0                                 13.0
#
#          parks_percent_change  transit_stations_percent_change  \
# 0                       -16.0                            -46.0
# 1                        -2.0                             -8.0
# 2                        -7.0                             -1.0
# 3                        -9.0                             -9.0
# 4                       -14.0                            -12.0
# ...                       ...                              ...
# 3076954                 103.0                             11.0
# 3076955                 106.0                              3.0
# 3076956                 103.0                             -4.0
# 3076957                  87.0                              6.0
# 3076958                 100.0                              9.0
#
#          workplace_percent_change  residential_percent_change
# 0                           -72.0                        26.0
# 1                           -19.0                         7.0
# 2                           -17.0                         6.0
# 3                           -26.0                         8.0
# 4                           -25.0                         8.0
# ...                           ...                         ...
# 3076954                     -24.0                         0.0
# 3076955                     -21.0                         1.0
# 3076956                     -21.0                         1.0
# 3076957                     -21.0                        -1.0
# 3076958                     -21.0                         0.0
#
# [3076959 rows x 10 columns]

# %%
#connect to local database
rds_connection_string = "postgres:postgres@localhost:5432/project2"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
#chrck for tables
engine.table_names()
# Out:
# ['us_mobility_2021', 'vaccinations']

# %%
#load csv into database
vacc_df.to_sql(name="vaccinations", con=engine, if_exists="append", index=False)
# Out:
# ---------------------------------------------------------------------------
# NotNullViolation                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# NotNullViolation: null value in column "date" of relation "vaccinations" violates not-null constraint
# DETAIL:  Failing row contains (null, Alabama, 70861, 7270).
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-85-0e917cb13e29> in <module>
#       1 #load csv into database
# ----> 2 vacc_df.to_sql(name="vaccinations", con=engine, if_exists="append", index=False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.NotNullViolation) null value in column "date" of relation "vaccinations" violates not-null constraint
# DETAIL:  Failing row contains (null, Alabama, 70861, 7270).
#
# [SQL: INSERT INTO vaccinations (state, people_vaccinated, people_fully_vaccinated) VALUES (%(state)s, %(people_vaccinated)s, %(people_fully_vaccinated)s)]
# [parameters: ({'state': 'Alabama', 'people_vaccinated': 70861.0, 'people_fully_vaccinated': 7270.0}, {'state': 'Alabama', 'people_vaccinated': 74792.0, 'people_fully_vaccinated': 9245.0}, {'state': 'Alabama', 'people_vaccinated': 86956.0, 'people_fully_vaccinated': 13488.0}, {'state': 'Alabama', 'people_vaccinated': 114319.0, 'people_fully_vaccinated': 16346.0}, {'state': 'Alabama', 'people_vaccinated': 121113.0, 'people_fully_vaccinated': 17956.0}, {'state': 'Alabama', 'people_vaccinated': 144429.0, 'people_fully_vaccinated': 21345.0}, {'state': 'Alabama', 'people_vaccinated': 174317.0, 'people_fully_vaccinated': 24840.0}, {'state': 'Alabama', 'people_vaccinated': 193955.0, 'people_fully_vaccinated': 27422.0}  ... displaying 10 of 2405 total bound parameter sets ...  {'state': 'Wyoming', 'people_vaccinated': 91931.0, 'people_fully_vaccinated': 43289.0}, {'state': 'Wyoming', 'people_vaccinated': 92151.0, 'people_fully_vaccinated': 43596.0})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
